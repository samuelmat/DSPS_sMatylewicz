# %% [markdown]
# <a href="https://colab.research.google.com/github/samuelmat/DSPS_sMatylewicz/blob/master/HW6/SNdataLineFit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import scipy as sp
import matplotlib.pyplot as plt
import matplotlib
import matplotlib.cm as cm
from scipy import optimize
from scipy.optimize import curve_fit
import sklearn as skl
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# #### Objective: fit supernova cosmology data : the linear relationship between logarithm redshift and luminosity of supernovae is evidence of the expansion of the Universe. In this homework you will fit the supernova data with a line, in the next class we will discover evidence of the *accelerated* expansion of the Universe

# %% [markdown]
# # Get the data

# %% [markdown]
# Download the supernova (SN) data used in the Betoule 2014 paper https://arxiv.org/abs/1401.4064. The data can be obtained here
# http://supernovae.in2p3.fr/sdss_snls_jla/ReadMe.html
#
# As it says on the webpage: "The JLA C++ code and data are available from a single archive: jla_likelihood_v6.tgz".
# Download it and unpack it (untar unzip) within the notebook (mounting your drive on colab etc) and move the data to the folder /drive/My Drive/dsps/data
#
# The input data file is named jla_lcparams.txt

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
ls
# Out:
#  backplate.dxf
# 'Colab Notebooks'/
# 'CPEG202 Final 18-21 key.gdoc'
#  dsps/
#  dsps_2019/
#  ELEG310/
# 'Failure Analysis, Fixes, and Long Term Reliability Testing of Components for Electric Vehicles.gdoc'
#  First_Baptist_Church_New_Castle.docx
#  First_Baptist_Church_New_Castle.gdoc
# 'Getting started.pdf'
#  jla_likelihood_v6.tgz
#  jla_likelihood_v6.tgz.1
#  jla_likelihood_v6.tgz.2
# 'Miller _ Spoolman Environmental Science 13th txtbk.pdf'
#  Moist.gdoc
#  PHYS207/
#  Poster.gslides
#  prop.dxf
# 'Radar Presentation.gdoc'
#  SamMatylewicz.MOV
# 'Secret Santa.gdoc'
#  Sliders.zip
# 'UD GIV Engineering'/
# 'Untitled presentation.gslides'

# %%
# !wget http://supernovae.in2p3.fr/sdss_snls_jla/jla_likelihood_v6.tgz
# Out:
# --2019-10-18 00:48:51--  http://supernovae.in2p3.fr/sdss_snls_jla/jla_likelihood_v6.tgz
# Resolving supernovae.in2p3.fr (supernovae.in2p3.fr)... 134.158.152.153
# Connecting to supernovae.in2p3.fr (supernovae.in2p3.fr)|134.158.152.153|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 23716633 (23M) [application/x-gzip]
# Saving to: ‘jla_likelihood_v6.tgz.3’
#
# jla_likelihood_v6.t 100%[===================>]  22.62M  6.00MB/s    in 4.3s
#
# 2019-10-18 00:48:56 (5.29 MB/s) - ‘jla_likelihood_v6.tgz.3’ saved [23716633/23716633]

# %%
# !tar -xzvf jla_likelihood_v6.tgz -C "drive/My Drive/dsps"
# Out:
# tar: drive/My Drive/dsps: Cannot open: No such file or directory
# tar: Error is not recoverable: exiting now

# %%
cd "drive/My Drive"
# Out:
# [Errno 2] No such file or directory: 'drive/My Drive'
# /content/drive/My Drive

# %%
jla = pd.read_csv("dsps/jla_likelihood_v6/data/jla_lcparams.txt", sep=" ")

# %%
jla.head()
# Out:
#     #name      zcmb    zhel  dz  ...  set         ra       dec   biascor
# 0  03D1au  0.503084  0.5043   0  ...    1  36.043210 -4.037469  0.001697
# 1  03D1aw  0.580724  0.5820   0  ...    1  36.061634 -4.517158  0.000843
# 2  03D1ax  0.494795  0.4960   0  ...    1  36.097287 -4.720774  0.001692
# 3  03D1bp  0.345928  0.3470   0  ...    1  36.657235 -4.838779 -0.000270
# 4  03D1co  0.677662  0.6790   0  ...    1  36.567748 -4.935050 -0.002855
#
# [5 rows x 21 columns]

# %%
jla.describe()
# Out:
#              zcmb        zhel     dz  ...          ra         dec     biascor
# count  740.000000  740.000000  740.0  ...  740.000000  740.000000  740.000000
# mean     0.323804    0.324449    0.0  ...   93.551713    5.726200   -0.004195
# std      0.276869    0.276748    0.0  ...  119.504602   22.728815    0.006796
# min      0.010060    0.009370    0.0  ...  -55.207462  -66.485085   -0.036389
# 25%      0.124240    0.124418    0.0  ...    4.812357   -1.037904   -0.008439
# 50%      0.229045    0.230515    0.0  ...   36.667567    0.237261   -0.001083
# 75%      0.498216    0.499000    0.0  ...  190.881058    2.146795   -0.000380
# max      1.299106    1.300000    0.0  ...  359.635090   79.031740    0.002649
#
# [8 rows x 20 columns]

# %%
jla.columns
# Out:
# Index(['#name', 'zcmb', 'zhel', 'dz', 'mb', 'dmb', 'x1', 'dx1', 'color',
#        'dcolor', '3rdvar', 'd3rdvar', 'tmax', 'dtmax', 'cov_m_s', 'cov_m_c',
#        'cov_s_c', 'set', 'ra', 'dec', 'biascor'],
#       dtype='object')

# %% [markdown]
# Use pandas scatter matrix to see the relationship between variables (Lab6). If you look in HW5 you can see how to rotate the labels

# %%
pd.plotting.scatter_matrix(jla)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_misc.py:108: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=0.0, right=0.0
#   ax.set_xlim(boundaries_list[j])
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_misc.py:109: UserWarning: Attempting to set identical bottom==top results
# in singular transformations; automatically expanding.
# bottom=0.0, top=0.0
#   ax.set_ylim(boundaries_list[i])
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_misc.py:100: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=0.0, right=0.0
#   ax.set_xlim(boundaries_list[i])
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fb3155652e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3155123c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3154b8630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3154dfb38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb31548f0f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3154365f8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb31545cb70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb31540f160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb31540f198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3153dfc18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb31538e1d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb315336748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb31535ecc0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb31530e278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3152b67f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3152e0d68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb315293320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb315239898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb315261e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3152123c8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fb3151b8940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3151e2eb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb315193470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3151399e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb315161f60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb315114518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3150bba90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3150ee048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3150935c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb31503bb38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb31506d0f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb315014668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb314fbbbe0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb314fee198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb314f95710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb314f3dc88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb314f6e240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb314f157b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb314ec0d30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb314ef02e8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fb314e96860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb314e41dd8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb314e71390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb314e18908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb314dc2e80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb314df2438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb314d9b9b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb314d41f28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb314d734e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb314d1aa58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb314cc2fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb314cf2588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb314c9db00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb314c4e0b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb314c74630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb314c1dba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb314bcb160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb314bf46d8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb314b9cc50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb314b4e208>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fb314b74780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb314b1ecf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb314acf2b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb314a76828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb314aa0da0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb314a50358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3149f88d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb314a21e48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3149d1400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb314976978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3149a1ef0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3149524a8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3148f9a20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb314922f98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3148d3550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb31487aac8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3148ad080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3148565f8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3147fbb70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb31482e128>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fb3147d56a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb31477dc18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3147ae1d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb314755748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3146ffcc0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb31472f278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3146d67f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb31467ed68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3146b3320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb314659898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb314602e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3146313c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3145d9940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb314582eb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3145b1470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3145599e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb314502f60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb314532518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3144daa90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb31448d048>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fb3144b35c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb31445cb38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb31440d0f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3143b5668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3143dcbe0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb31438d198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb314335710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb31435ec88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb31430f240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3143347b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3142dfd30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3142902e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb314236860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb31425fdd8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb314212390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3141b9908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3141e0e80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb314193438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3141399b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb314162f28>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fb3141134e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3140b9a58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3140e2fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb314091588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb31403bb00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb31406d0b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb314014630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb313fbdba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb313fed160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb313f936d8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb313f3ec50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb313f70208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb313f15780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb313ec0cf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb313eef2b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb313e96828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb313e3eda0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb313e71358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb313e158d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb313dc0e48>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fb313df1400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb313d98978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb313d41ef0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb313d724a8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb313d1aa20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb313cc2f98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb313cf4550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb313c9bac8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb313c4b080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb313c725f8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb313c1bb70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb313bcc128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb313bf36a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb313b9ec18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb313b4d1d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb313af6748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb313b1fcc0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb313acf278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb313a757f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb313a9ed68>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fb313a51320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3139f8898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb313a20e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3139d13c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb313979940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3139a1eb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb313952470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3138f99e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb313922f60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3138d5518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb31387ba90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3138ae048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3138545c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3137fab38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb31382d0f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3137d5668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb31377dbe0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3137af198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb313756710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3136fec88>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fb313730240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3136d67b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb31367fd30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3136b02e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb313657860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3135ffdd8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb313630390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3135d7908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb313581e80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3135b2438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb31355a9b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb313502f28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3135314e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3134dba58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb313484fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3134b1588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb31345bb00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb31340e0b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb313434630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3133dcba8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fb31338f160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3133356d8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb31335dc50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb31330e208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3132b5780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3132decf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3132902b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb313237828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb31325fda0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb313210358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3131b78d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3131dee48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb313192400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb313138978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb313161ef0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3131114a8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3130b9a20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3130e1f98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb313093550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb31303bac8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fb31306b080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3130135f8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb312fbcb70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb312fee128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb312f966a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb312f3dc18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb312f6f1d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb312f16748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb312ebdcc0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb312ef0278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb312e947f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb312e3ed68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb312e71320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb312e17898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb312dbfe10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb312df13c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb312d97940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb312d3feb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb312d70470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb312d179e8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fb312cc1f60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb312cf1518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb312c99a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb312c4d048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb312c735c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb312c1cb38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb312bcd0f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb312b75668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb312b9dbe0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb312b4f198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb312af6710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb312b1ec88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb312acd240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb312a777b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb312a9ed30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb312a512e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3129f8860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb312a21dd8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3129d1390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb312979908>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fb3129a0e80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb312951438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3128fa9b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb312921f28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3128d14e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb31287aa58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3128a3fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb312851588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3127fdb00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb31282f0b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3127d5630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb31277cba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3127af160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3127576d8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3126fec50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb312730208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3126d7780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb31267ecf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3126b02b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb312657828>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fb3125ffda0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb312632358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3125d88d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb312581e48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3125b2400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb312558978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb312503ef0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3125324a8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3124dba20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb312482f98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3124b2550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb31245cac8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb31240e080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3124345f8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3123dcb70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb31238f128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3123356a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb31235dc18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3123111d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3122b7748>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fb3122decc0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb312291278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3122367f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb31225ed68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb312211320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3121b9898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3121e1e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3121913c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb31213a940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb312161eb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb312113470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3120ba9e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3120e1f60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb312094518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb31203da90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb31206f048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3120155c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb311fbcb38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb311fed0f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb311f95668>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fb311f3dbe0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb311f6f198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb311f16710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb311ebfc88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb311eef240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb311e997b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb311e3fd30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb311e702e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb311e19860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb311dc2dd8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb311df2390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb311d99908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb311d42e80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb311d72438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb311d1a9b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb311cc4f28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb311cf44e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb311c9da58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb311c46fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb311bf5588>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fb311c1db00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb311bd20b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb311b77630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb311b9eba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb311b51160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb311af76d8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb311b1fc50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb311ad2208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb311a77780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb311aa1cf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb311a512b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3119fa828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb311a21da0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3119d2358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb31197b8d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3119a3e48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb311952400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3118fb978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb311924ef0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3118d44a8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fb31187ea20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3118a5f98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb311855550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3117feac8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb311830080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3117d75f8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb31177eb70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3117b2128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3117576a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3116fec18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3117301d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3116d8748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb311680cc0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3116b1278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3116587f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb311600d68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb311632320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3115da898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb311583e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3115b43c8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fb31155d940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb311503eb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb311534470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3114da9e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb311484f60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb311437518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb31145da90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb311410048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3113b75c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3113ddb38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3113900f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb311337668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb311360be0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb311311198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3112b8710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3112e0c88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb311292240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3112397b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb311261d30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3112122e8>]],
#       dtype=object)

# %% [markdown]
# The target variables for our analysis are redshift and brightness: "zcmb" and "mb". This an exercise about fitting lines to data. Why does it lot look like there is a line relationship between them? How can does the relationship look? Plot the "zcmb" vs "mb". Include the y uncertainty which is reported in "dmb". Plot each data point with a different color based on the survey it comes from. The survey data is indicated by the variable "set". To do it you can use the dataframe plotting methods (```df.plot.scatter()```),  or pylab:  ```pylab.scatter()```, or ```pylab.plot()``` --asking to plot the data as point ('.')-- but for each the way you relate the color to a column value is a bit different. Stackoverflow is your friend here!

# %%
zcmb = jla["zcmb"].copy()
zcmb.shape
# Out:
# (740,)

# %%
mb = jla["mb"].copy()
mb.shape
# Out:
# (740,)

# %%
dmb = jla["dmb"].copy()
dmb.shape
# Out:
# (740,)

# %%
fig = plt.figure(figsize = (10, 10));
ax = fig.add_subplot(1, 1, 1)
sc = ax.scatter(zcmb,mb, s = 0, c = zcmb);
norm = matplotlib.colors.Normalize(vmin=min(mb), vmax=max(mb), clip=True);
mapper = cm.ScalarMappable(norm=norm, cmap='viridis');
m = max(mb)
n = min(mb)
time_color = np.array([(mapper.to_rgba(m + n - 0.75*v - 7)) for v in mb]);

for x, y, e, color in zip(zcmb, mb, dmb, time_color):
  ax.plot(x, y, '.', color=color)
  ax.errorbar(x, y, e, color=color)
ax.set_title("Brightness vs Redshift", fontsize = "xx-large")
ax.set_xlabel("zcmb", fontsize = "xx-large")
ax.set_ylabel("mb", fontsize = "xx-large");

# %% [markdown]
# caption: scatter plot of zcmb and mb

# %% [markdown]
# It is a **power law**, which means it will be linear in logarithmic space - specifically in log10(_x_) vs natural _y_ space.
#
# Replot the data with natural y axis and logarithmic x axis, you can do that by taking the log of the data and then plotting it or by using plot functionalities (e.g. for ```df.plot.scatter()``` you can use ```logx=True```)
#
# Note that when we talk about log we (generally) talk about log base 10!

# %%
fig = plt.figure(figsize = (10, 10));
ax = fig.add_subplot(1, 1, 1)
ax.set_xscale('log')

for x, y, e, color in zip(zcmb, mb, dmb, time_color):
  ax.plot(x, y, '.', color=color)
  ax.errorbar(x, y, e, color=color)
ax.set_title("Brightness vs Redshift", fontsize = "xx-large")
ax.set_xlabel("log10(zcmb)", fontsize = "xx-large")
ax.set_ylabel("mb", fontsize = "xx-large");

# %% [markdown]
# caption: this is a scatter plot of log(zcmb) vs mb

# %% [markdown]
# # Fit a line to the data with scipy
#
# For each model you fit below you should make a plot of the data and the model. Consider your fit to the data with the uncertainties your "baseline fit"

# %% [markdown]
# Like we did in class: fit a line using ```scipy.optimize``` (lab 5). Do it without and with the uncertainties on your _y_ data (the ```curvefit``` argument to include uncertainties in the endogenous variable is ```sigma```). Report the variace and the covariance by printing your mode uncertainties explicitly as below:

# %%
#delete
def line(x, a, b):
  return a * x + b

# %%
logZcmb = np.log10(zcmb)

params1, cov1 = curve_fit(line, logZcmb, mb)
a1, b1 = params1
da1, db1 = np.sqrt(cov1[0][0]), np.sqrt(cov1[1][1])

# %%
print("not accounting for uncertainty:")
print("slope: %.1f \u00B1 %.3f" % (a1, da1))
print("intercept: %.1f \u00B1 %.3f" % (b1, db1))
print("parameters covariance: %.5f " % cov1[0][1])
# Out:
# not accounting for uncertainty:
# slope: 5.4 ± 0.022
# intercept: 24.7 ± 0.019
# parameters covariance: 0.00035

# %%
sig = np.zeros(len(mb)) + np.std(dmb)
params2, cov2 = curve_fit(line, logZcmb, mb, sigma = dmb, absolute_sigma = True)
a2, b2 = params2
da2, db2 = np.sqrt(cov2[0][0]), np.sqrt(cov2[1][1])

# %%
print("accounting for uncertainty:")
print("slope: %.1f \u00B1 %.3f" % (a2, da2))
print("intercept: %.1f \u00B1 %.3f" % (b2, db2))
print("parameters covariance: %.5f " % cov2[0][1])
# Out:
# accounting for uncertainty:
# slope: 5.4 ± 0.009
# intercept: 24.7 ± 0.007
# parameters covariance: 0.00005

# %% [markdown]
# hint: remember to sort the data!

# %% [markdown]
# plot the data like you did above and the model you just created including the uncertainty band (look at lab5: there is a mistake we made in class which I corrected in the version I uploaded)

# %%
fig = plt.figure(figsize = (10, 10));
ax = fig.add_subplot(1, 1, 1)
ax.scatter(logZcmb, mb, s = 1)
ax.errorbar(logZcmb, mb, xerr=None, yerr=dmb, fmt='.')

modelMb2 = line(logZcmb, a2, b2)
maxMb2 = line(logZcmb, a2 + np.sqrt(cov2[0][0]), b2 + np.sqrt(cov2[1][1]))
minMb2 = line(logZcmb, a2 - np.sqrt(cov2[0][0]), b2 - np.sqrt(cov2[1][1]))

ax.plot(logZcmb, modelMb2)
ax.fill_between(logZcmb, maxMb2, minMb2, color = 'green', alpha = 0.5)

ax.set_title("Brightness vs Redshift", fontsize = "xx-large")
ax.set_xlabel("log10(zcmb)", fontsize = "xx-large")
ax.set_ylabel("mb", fontsize = "xx-large");

# %% [markdown]
# caption: scatter plot of log(zcmb) vs mb with a linear fit and errorbars for uncertainty

# %% [markdown]
# Compare the *model* values and uncertainty you obtained by fitting the model with and without including the uncertainties on the y values.  Comment on your findings.

# %% [markdown]
# they are almost identical

# %% [markdown]
# Now fit the data using only 1 every 20 points - use this: https://stackoverflow.com/questions/25876640/subsampling-every-nth-entry-in-a-numpy-array
#
# Plot the new model and its uncertainty band and comment on the model: how do the three models compare?

# %%
params3, cov3 = curve_fit(line, logZcmb[1::20], mb[1::20])
a3, b3 = params3
da3, db3 = np.sqrt(cov3[0][0]), np.sqrt(cov3[1][1])

# %%
print("every 20th value:")
print("slope: %.1f \u00B1 %.3f" % (a3, da3))
print("intercept: %.1f \u00B1 %.3f" % (b3, db3))
print("parameters covariance: %.5f " % cov3[0][1])
# Out:
# every 20th value:
# slope: 5.5 ± 0.088
# intercept: 24.7 ± 0.073
# parameters covariance: 0.00523

# %%
fig = plt.figure(figsize = (10, 10));
ax = fig.add_subplot(1, 1, 1)
ax.scatter(logZcmb, mb, s = 1)
ax.errorbar(logZcmb, mb, xerr=None, yerr=dmb, fmt='.')

modelMb3 = line(logZcmb, a3, b3)
maxMb3 = line(logZcmb, a3 + da3, b3 + db3)
minMb3 = line(logZcmb, a3 - da3, b3 - db3)

ax.plot(logZcmb, modelMb3)
ax.fill_between(logZcmb, maxMb3, minMb3, color = 'green', alpha = 0.5)

ax.set_title("Brightness vs Redshift", fontsize = "xx-large")
ax.set_xlabel("log10(zcmb)", fontsize = "xx-large")
ax.set_ylabel("mb", fontsize = "xx-large");

# %% [markdown]
# caption: the fit for every 20th value compared to others

# %% [markdown]
# # Fit a quadratic equation

# %% [markdown]
# Use the same function ```curve_fit()``` to fit a quadratic equation to the data.
# The equation is below
#
# Plot your data, your original model which included uncertainties, and the current quadratic model

# %%
def quad(x, a, b, c):
    '''Quadratic equation
    Input:
    x: array-like, the exogenous variable
    a: parameters of the quadratic term
    b: parameter of the linear term
    c: intercept
    
    '''
    return a * x**2 + b * x + c

# %%
params4, cov4 = curve_fit(quad, logZcmb[1::20], mb[1::20])
a4, b4, c4 = params4
da4, db4, dc4 = np.sqrt(cov4[0][0]), np.sqrt(cov4[1][1]), np.sqrt(cov4[2][2])

# %%
print("quadratic fit:")
print("x2 term: %.1f \u00B1 %.3f" % (a4, da4))
print("x1 term: %.1f \u00B1 %.3f" % (b4, db4))
print("x0 term: %.1f \u00B1 %.3f" % (c4, dc4))
print("parameters covariance: %.5f " % cov4[0][1])
# Out:
# quadratic fit:
# x2 term: 0.3 ± 0.139
# x1 term: 6.1 ± 0.260
# x0 term: 24.9 ± 0.099
# parameters covariance: 0.03438

# %%
fig = plt.figure(figsize = (10, 10));
ax = fig.add_subplot(1, 1, 1)
ax.scatter(logZcmb, mb, s = 1)
ax.errorbar(logZcmb, mb, xerr=None, yerr=dmb, fmt='.')

modelMb4 = quad(logZcmb, a4, b4, c4)

ax.plot(logZcmb, modelMb2, label="line fit", linewidth = 1)
ax.plot(logZcmb, modelMb4, label="quadratic fit", linewidth = 0.5)

ax.set_title("Brightness vs Redshift", fontsize = "xx-large")
ax.set_xlabel("log10(zcmb)", fontsize = "xx-large")
ax.set_ylabel("mb", fontsize = "xx-large")
ax.legend(['linear fit', 'quadratic fit'], loc = 'upper left', fontsize = 15)

# %% [markdown]
# caption: linear fit vs quadratic fit

# %% [markdown]
# # Now fit the data with sklearn
# like we did in class (lab 5): create a regressor linear model and fit the data to it. Predict the y values based on the input data. Make the usual plot of data and model including your baseline model with scipy

# %%
regr = skl.linear_model.LinearRegression()
regr.fit(np.atleast_2d(logZcmb).T, mb)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
fig = plt.figure(figsize = (10, 10));
ax = fig.add_subplot(1, 1, 1)
ax.errorbar(logZcmb, mb, yerr = dmb, fmt = '.')
ax.set_title("Brightness vs Redshift", fontsize = "xx-large")
ax.set_xlabel("log10(zcmb)", fontsize = "xx-large")
ax.set_ylabel("mb", fontsize = "xx-large");

ax.plot(logZcmb, regr.predict(np.atleast_2d(logZcmb).T), '-', label = "sklearn LinearRegression()")
ax.plot(logZcmb, modelMb2, '-', label = "scipy curve_fit")
ax.legend(['sklearn LinearRegression()', 'scipy curve_fit'], loc = 'upper left', fontsize = 15)

# %%
scipyR2 = r2_score(mb, modelMb2)
sklearnR2 = np.round(regr.score(np.atleast_2d(logZcmb).T, mb), 3)

print('Scipy model R2: %.3f' % scipyR2)
print("Sklearn model R2: %.3f" % sklearnR2)
# Out:
# Scipy model R2: 0.987
# Sklearn model R2: 0.987

# %% [markdown]
# caption: using sklearn vs curve fit

# %% [markdown]
# # Cross valudation: Split your data into a training and test set
# this is the "signature" of the machine learning approach. While this can be done using simply a random number generator
# (see example)
#
# do it using the sklear capabilities: ```skl.model_selection.train_test_split```. Read abnout the ```stratify``` funcionality of this method: it allows you to create unbiased train-test samples. In this case it is not necessary but it may be useful in your future!

# %%
# handmade train-test split
Nall = len(jla)
Ntrain = int(Nall * 0.75)
train = np.random.randint(0, high=Nall, size=Ntrain)
test = np.setdiff1d(np.arange(Nall), train)
X_train, y_train = jla.zcmb[train], jla.mb[train]
X_test, y_test = jla.zcmb[test], jla.mb[test]
plt.plot(X_train, y_train, 'k.', label="train")
plt.plot(X_test, y_test, 'r.', alpha=0.5, label="test")
plt.xlabel("X")
plt.ylabel("y")
plt.legend()

# %%
#instead use sklern to split
X_train, X_test, y_train, y_test = skl.model_selection.train_test_split(zcmb, mb, test_size = 0.5, random_state = 467)

fig = plt.figure(figsize = (7.5, 5));
ax = fig.add_subplot(1, 1, 1)
ax.plot(X_train, y_train, 'k.', label="train")
ax.plot(X_test, y_test, 'r.', alpha=0.5, label="test")
ax.set_title("Brightness vs Redshift", fontsize = "xx-large")
ax.set_xlabel("zcmb")
ax.set_ylabel("mb")
ax.legend(fontsize = 13)

# %% [markdown]
# caption: training data vs test data

# %% [markdown]
# Plot the data, the baseline mode, and the new model, but colorcode the data based on the training or test set (instead othe survey it comes from like you had done before)

# %%
X_train, X_test, y_train, y_test = skl.model_selection.train_test_split(logZcmb, mb, test_size = 0.5, random_state = 467)

params5, cov5 = curve_fit(line, X_train, y_train)
a5, b5 = params5
modelMb5 = line(X_train, a5, b5)

# %%
regr = skl.linear_model.LinearRegression()
regr.fit(np.atleast_2d(X_train).T, y_train)
modelMb6 = regr.predict(np.atleast_2d(logZcmb).T)

fig = plt.figure(figsize = (10, 10));
ax = fig.add_subplot(1, 1, 1)

ax.plot(X_train, y_train, 'k.', label="train")
ax.plot(X_test, y_test, 'r.', alpha=0.5, label="test")

ax.plot(logZcmb, modelMb6, '-', label = "sklearn LinearRegression()", color = 'C1')
ax.plot(logZcmb, modelMb2, '-', label = "scipy curve_fit", color = "C2")

ax.set_title("Brightness vs Redshift", fontsize = "xx-large")
ax.set_xlabel("log(zcmb)")
ax.set_ylabel("mb")
ax.legend(fontsize = 13)

# %% [markdown]
# caption: sklean vs scipy and training vs testing groups

# %% [markdown]
# Calculate the scores of the train and test set. Make considerations about the quality of the model including how robust it is (is it overfitting?)

# %%
scipyR2 = r2_score(y_train, modelMb5)
sklearnR2 = np.round(regr.score(np.atleast_2d(X_train).T, y_train), 3)
print("training:")
print("scipy model r2: %.3f" % scipyR2)
print("sklearn model r2: %.3f" % sklearnR2)
# Out:
# training:
# scipy model r2: 0.988
# sklearn model r2: 0.988

# %%
scipyR2 = r2_score(y_test, line(X_test, a5, b5))
sklearnR2 = np.round(regr.score(np.atleast_2d(X_test).T, y_test), 3)
print("testing")
print("scipy model r2: %.3f" % scipyR2)
print("sklearn model r2: %.3f" % sklearnR2)
# Out:
# testing
# scipy model r2: 0.987
# sklearn model r2: 0.987

# %% [markdown]
# they are accurate and not overfitting
