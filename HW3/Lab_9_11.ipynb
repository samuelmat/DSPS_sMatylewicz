# %% [markdown]
# <a href="https://colab.research.google.com/github/samuelmat/DSPS_sMatylewicz/blob/master/HW3/Lab_9_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
rain=pd.read_csv("https://raw.githubusercontent.com/fedhere/DSPS/master/labs/1865331.csv")

# %%
rainonly = rain[["DATE", "PRCP"]]

# %%
# Out:
# Empty DataFrame
# Columns: [DATE, PRCP, date]
# Index: []

# %%
rainonly['date'] = pd.to_datetime(rainonly.DATE)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
recentonly = rainonly[rainonly['date'] > pd.to_datetime("2018/01/01")].describe()

# %%
recentonly
# Out:
#              PRCP
# count  615.000000
# mean     0.162504
# std      0.365007
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      0.120000
# max      2.450000

# %%
import scipy as sp
from scipy import stats

# %%
stats.zscore(recentonly)
# Out:
# array([[ 2.64573207],
#        [-0.37933934],
#        [-0.37834301],
#        [-0.38013888],
#        [-0.38013888],
#        [-0.38013888],
#        [-0.37954847],
#        [-0.3680846 ]])

# %%
(0.137-0.162504)/(0.38/np.sqrt(615))
# Out:
# -1.664417452430633
